# %% [markdown]
# <h2>Random Forest</h2>
# <a href="https://colab.research.google.com/github/thedhruvish/ml-algorithms-project/blob/main/random-forest/project-Admission.ipynb">
# <img src="https://raw.githubusercontent.com/thedhruvish/dataset-machine-learning/refs/heads/main/public/colab.svg" alt="colab svg"></a>
# <h3>Admission Dataset </h3>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/thedhruvish/dataset-machine-learning/refs/heads/main/ml-algorithms-project/Admission.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         400 non-null    int64
#  1   GRE Score          400 non-null    int64
#  2   TOEFL Score        400 non-null    int64
#  3   University Rating  400 non-null    int64
#  4   SOP                400 non-null    float64
#  5   LOR                400 non-null    float64
#  6   CGPA               400 non-null    float64
#  7   Research           400 non-null    int64
#  8   Chance of Admit    400 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 28.2 KB

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df = df.drop(columns=['Serial No.'])

# %%
df
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Chance of Admit
# 0                0.92
# 1                0.76
# ...

# %%
X = df.drop(columns=['Research'])
y = df['Research']

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=51)
rf = RandomForestClassifier()

# %%
rf
# Out:
# RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(X_test)

# %%
y_test
# Out:
# 310    1
# 345    0
# 111    1
# 355    0
# 247    0
#       ..
# 100    1
# 123    0
# 239    0
# 170    1
# 275    1
# Name: Research, Length: 80, dtype: int64

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[30,  6],
#        [14, 30]])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.75

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[30  6]
#  [14 30]]

# %%
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.83      0.75        36
#            1       0.83      0.68      0.75        44
#
#     accuracy                           0.75        80
#    macro avg       0.76      0.76      0.75        80
# weighted avg       0.77      0.75      0.75        80
